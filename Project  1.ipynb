# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# data collection

# %%
file = pd.read_csv("austo_automobile.csv")

# %%
file
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
# Data profiling

# %%
file.shape
# Out:
# (1581, 14)

# %%
file.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %%
file.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1475.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    19573.149277
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38300.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
file.head(5)
# to show top 5 records
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
file.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
file.duplicated().sum()
# Out:
# np.int64(0)

# %%
file.Gender.unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
file.Profession.unique()
# Out:
# array(['Business', 'Salaried'], dtype=object)

# %%
file.Gender.value_counts()
# Out:
# Gender
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: count, dtype: int64

# %%
file.Make.unique()
# Out:
# array(['SUV', 'Sedan', 'Hatchback'], dtype=object)

# %%
file.Marital_status.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
file.Education.unique()
# Out:
# array(['Post Graduate', 'Graduate'], dtype=object)

# %%
file.Personal_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
file.House_loan.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Data cleaning

# %%
file.Gender = file.Gender.replace(["Femal","Femle"],["Female","Female"])
# replace misspelled word with correct word

# %%
file.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
file.Gender = file.Gender.fillna("Male")
# fill all the null values with mode value which is male

# %%
file.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
file.Partner_salary = file.Total_salary - file.Salary
# substract the sallery with total sallery to fill missing values in partner sallery.

# %%
file.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
file.Gender.value_counts()
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %%
sns.countplot(file,x=file.Gender,hue= file.Gender)
# Show the comparision between male and female count
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(file,x=file.Profession,hue= file.Profession)
# Out:
# <Axes: xlabel='Profession', ylabel='count'>

# %%
sns.countplot(file,x=file.Education,hue= file.Education)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(file,x=file.Marital_status,hue= file.Marital_status)
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(file,x=file.Personal_loan,hue= file.Personal_loan)
# Out:
# <Axes: xlabel='Personal_loan', ylabel='count'>

# %%
sns.countplot(file,x=file.Partner_working,hue= file.Partner_working)
# Out:
# <Axes: xlabel='Partner_working', ylabel='count'>

# %%
sns.countplot(file,x=file.Make,hue= file.Make)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
sns.histplot(file.Age)
# distribution of age column
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(file.Salary)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(file.No_of_Dependents)
# Out:
# <Axes: xlabel='No_of_Dependents', ylabel='Count'>

# %%
sns.histplot(file.Partner_salary)
# Out:
# <Axes: xlabel='Partner_salary', ylabel='Count'>

# %%
sns.histplot(file.Total_salary)
# Out:
# <Axes: xlabel='Total_salary', ylabel='Count'>

# %%
sns.histplot(file.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
pd.crosstab(file.Gender,file.Make)
# Out:
# Make    Hatchback  SUV  Sedan
# Gender
# Female         15  173    141
# Male          567  124    561

# %%
pd.crosstab(file.Gender,file.Make).plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %%
# EDA :

# %%
file.Gender.value_counts()
# Out:
# Gender
# Male      1252
# Female     329
# Name: count, dtype: int64

# %%
male=file[file.Gender=="Male"][["Gender","Make"]]

# %%
female=file[file.Gender=="Female"][["Gender","Make"]]

# %%
sample1 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sample1
# Out:
#            Male
# Make
# Hatchback   150
# SUV          34
# Sedan       145

# %%
sample2 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sample2
# Out:
#            Male
# Make
# Hatchback   142
# SUV          25
# Sedan       162

# %%
sample3 = male.sample(329).groupby("Make").count().rename(columns={"Gender":"Male"})

# %%
sample3
# Out:
#            Male
# Make
# Hatchback   149
# SUV          34
# Sedan       146

# %%
fem1 = female.sample(329).groupby("Make").count().rename(columns={"Gender":"Female"})

# %%
fem1
# Out:
#            Female
# Make
# Hatchback      15
# SUV           173
# Sedan         141

# %%
suvm = [sample1.iloc[1][0],sample2.iloc[1][0],sample3.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\137440993.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvm = [sample1.iloc[1][0],sample2.iloc[1][0],sample3.iloc[1][0]]

# %%
suvf = [fem1.iloc[1][0],fem1.iloc[1][0],fem1.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\4126913502.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvf = [fem1.iloc[1][0],fem1.iloc[1][0],fem1.iloc[1][0]]

# %%
suvm
# Out:
# [np.int64(34), np.int64(25), np.int64(34)]

# %%
suvf
# Out:
# [np.int64(173), np.int64(173), np.int64(173)]

# %%
SUV = pd.DataFrame({"Male":suvm,"Female":suvf},index=["sample1","sample2","sample3"])

# %%
SUV
# Out:
#          Male  Female
# sample1    34     173
# sample2    25     173
# sample3    34     173

# %%
SUV.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that Female candidates are more interested in SUV than male

# %%
sedanm = [sample1.iloc[2][0],sample2.iloc[2][0],sample3.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2052840617.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedanm = [sample1.iloc[2][0],sample2.iloc[2][0],sample3.iloc[2][0]]

# %%
sedanf = [fem1.iloc[2][0],fem1.iloc[2][0],fem1.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\455743213.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedanf = [fem1.iloc[2][0],fem1.iloc[2][0],fem1.iloc[2][0]]

# %%
sedanm
# Out:
# [np.int64(145), np.int64(162), np.int64(146)]

# %%
sedanf
# Out:
# [np.int64(141), np.int64(141), np.int64(141)]

# %%
SEDAN = pd.DataFrame({"Male":sedanm,"Female":sedanf},index=["sample1","sample2","sample3"])

# %%
SEDAN
# Out:
#          Male  Female
# sample1   145     141
# sample2   162     141
# sample3   146     141

# %%
SEDAN.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that Female and male are allmost same interested in SEDAN.

# %%
hatchbackm = [sample1.iloc[0][0],sample2.iloc[0][0],sample3.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\4034103581.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackm = [sample1.iloc[0][0],sample2.iloc[0][0],sample3.iloc[0][0]]

# %%
hatchbackf = [fem1.iloc[0][0],fem1.iloc[0][0],fem1.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\183728874.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackf = [fem1.iloc[0][0],fem1.iloc[0][0],fem1.iloc[0][0]]

# %%
hatchbackm
# Out:
# [np.int64(150), np.int64(142), np.int64(149)]

# %%
hatchbackf
# Out:
# [np.int64(15), np.int64(15), np.int64(15)]

# %%
HATCHBACK = pd.DataFrame({"Male":hatchbackm,"Female":hatchbackf},index=["sample1","sample2","sample3"])

# %%
HATCHBACK
# Out:
#          Male  Female
# sample1   150      15
# sample2   142      15
# sample3   149      15

# %%
HATCHBACK.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that male candidates are more interested in HATCHBACK than female

# %%
# Education
# marital status
# personal loan
# house loan

# %%
#  camparision 2

# %%
pd.crosstab(file.Education,file.Make)
# Out:
# Make           Hatchback  SUV  Sedan
# Education
# Graduate             220  117    259
# Post Graduate        362  180    443

# %%
pd.crosstab(file.Education,file.Make).plot.bar()
# Out:
# <Axes: xlabel='Education'>

# %%
file.Education.value_counts()
# Out:
# Education
# Post Graduate    985
# Graduate         596
# Name: count, dtype: int64

# %%
postg= file[file.Education=="Post Graduate"][["Education","Make"]]

# %%
graduate = file[file.Education=="Graduate"][["Education","Make"]]

# %%
sample11 = postg.sample(596).groupby("Make").count().rename(columns={"Education":"Post Graduate"})

# %%
sample11
# Out:
#            Post Graduate
# Make
# Hatchback            223
# SUV                  100
# Sedan                273

# %%
sample12 = postg.sample(596).groupby("Make").count().rename(columns={"Education":"Post Graduate"})

# %%
sample12
# Out:
#            Post Graduate
# Make
# Hatchback            216
# SUV                  113
# Sedan                267

# %%
sample13 = postg.sample(596).groupby("Make").count().rename(columns={"Education":"Post Graduate"})

# %%
sample13
# Out:
#            Post Graduate
# Make
# Hatchback            218
# SUV                  111
# Sedan                267

# %%
graduate1 = graduate.sample(596).groupby("Make").count().rename(columns={"Education":"Graduate"})

# %%
graduate1
# Out:
#            Graduate
# Make
# Hatchback       220
# SUV             117
# Sedan           259

# %%
suvp = [sample11.iloc[1][0],sample12.iloc[1][0],sample13.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2456990001.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvp = [sample11.iloc[1][0],sample12.iloc[1][0],sample13.iloc[1][0]]

# %%
suvg = [graduate1.iloc[1][0],graduate1.iloc[1][0],graduate1.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2511956548.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvg = [graduate1.iloc[1][0],graduate1.iloc[1][0],graduate1.iloc[1][0]]

# %%
suvp
# Out:
# [np.int64(100), np.int64(113), np.int64(111)]

# %%
suvg
# Out:
# [np.int64(117), np.int64(117), np.int64(117)]

# %%
SUVE = pd.DataFrame({"Post Graduate":suvp,"Graduate":suvg},index=["sample11","sample12","sample13"])

# %%
SUVE
# Out:
#           Post Graduate  Graduate
# sample11            100       117
# sample12            113       117
# sample13            111       117

# %%
SUVE.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that Graduate candidates are more interested in SUV than Post Graduate

# %%
hatchbackp = [sample11.iloc[0][0],sample12.iloc[0][0],sample13.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3241229120.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackp = [sample11.iloc[0][0],sample12.iloc[0][0],sample13.iloc[0][0]]

# %%
hatchbackg = [graduate1.iloc[0][0],graduate1.iloc[0][0],graduate1.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\566055245.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackg = [graduate1.iloc[0][0],graduate1.iloc[0][0],graduate1.iloc[0][0]]

# %%
hatchbackp
# Out:
# [np.int64(223), np.int64(216), np.int64(218)]

# %%
hatchbackg
# Out:
# [np.int64(220), np.int64(220), np.int64(220)]

# %%
HATCHBACKE = pd.DataFrame({"Post Graduate":hatchbackp,"Graduate":hatchbackg},index=["sample11","sample12","sample13"])

# %%
HATCHBACKE
# Out:
#           Post Graduate  Graduate
# sample11            223       220
# sample12            216       220
# sample13            218       220

# %%
HATCHBACKE.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that Post Graduate and Graduate are allmost same interested in HATCHBACK.

# %%
sedanp =[sample11.iloc[2][0],sample12.iloc[2][0],sample13.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2750628736.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedanp =[sample11.iloc[2][0],sample12.iloc[2][0],sample13.iloc[2][0]]

# %%
sedang = [graduate1.iloc[2][0],graduate1.iloc[2][0],graduate1.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3273194659.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedang = [graduate1.iloc[2][0],graduate1.iloc[2][0],graduate1.iloc[2][0]]

# %%
sedanp
# Out:
# [np.int64(273), np.int64(267), np.int64(267)]

# %%
sedang
# Out:
# [np.int64(259), np.int64(259), np.int64(259)]

# %%
SEDANE = pd.DataFrame({"Post Graduate":sedanp,"Graduate":sedang},index=["sample11","sample12","sample13"])

# %%
SEDANE
# Out:
#           Post Graduate  Graduate
# sample11            273       259
# sample12            267       259
# sample13            267       259

# %%
SEDANE.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearly visible that Post Graduate candidates are more interested in SEDAN than Graduate

# %%
#  camparision 3

# %%
pd.crosstab(file.Marital_status,file.Make)
# Out:
# Make            Hatchback  SUV  Sedan
# Marital_status
# Married               498  281    664
# Single                 84   16     38

# %%
pd.crosstab(file.Marital_status,file.Make).plot.bar()
# Out:
# <Axes: xlabel='Marital_status'>

# %%
file.Marital_status.value_counts()
# Out:
# Marital_status
# Married    1443
# Single      138
# Name: count, dtype: int64

# %%
married = file[file.Marital_status=="Married"][["Marital_status","Make"]]

# %%
single = file[file.Marital_status=="Single"][["Marital_status","Make"]]

# %%
sample21 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sample21
# Out:
#            Married
# Make
# Hatchback       53
# SUV             23
# Sedan           62

# %%
sample22 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sample22
# Out:
#            Married
# Make
# Hatchback       44
# SUV             29
# Sedan           65

# %%
sample23 = married.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Married"})

# %%
sample23
# Out:
#            Married
# Make
# Hatchback       48
# SUV             31
# Sedan           59

# %%
single1 = single.sample(138).groupby("Make").count().rename(columns={"Marital_status":"Single"})

# %%
single1
# Out:
#            Single
# Make
# Hatchback      84
# SUV            16
# Sedan          38

# %%
suvM = [sample21.iloc[1][0],sample22.iloc[1][0],sample23.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3345750881.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvM = [sample21.iloc[1][0],sample22.iloc[1][0],sample23.iloc[1][0]]

# %%
suvS = [single1.iloc[1][0],single1.iloc[1][0],single1.iloc[1][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2751210445.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvS = [single1.iloc[1][0],single1.iloc[1][0],single1.iloc[1][0]]

# %%
SUVm = pd.DataFrame({"Married":suvM,"Single":suvS},index=["sample21","sample22","sample23"])

# %%
SUVm
# Out:
#           Married  Single
# sample21       23      16
# sample22       29      16
# sample23       31      16

# %%
SUVm.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that married people are more intersted in SUV than Single.

# %%
hatchbackM = [sample21.iloc[0][0],sample22.iloc[0][0],sample23.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\1161313336.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackM = [sample21.iloc[0][0],sample22.iloc[0][0],sample23.iloc[0][0]]

# %%
hatchbackS = [single1.iloc[0][0],single1.iloc[0][0],single1.iloc[0][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3770828907.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackS = [single1.iloc[0][0],single1.iloc[0][0],single1.iloc[0][0]]

# %%
hatchbackM
# Out:
# [np.int64(53), np.int64(44), np.int64(48)]

# %%
hatchbackS
# Out:
# [np.int64(84), np.int64(84), np.int64(84)]

# %%
HATCHBACKm = pd.DataFrame({"married":hatchbackM,"single":hatchbackS},index=["sample21","sample22","sample23"])

# %%
HATCHBACKm
# Out:
#           married  single
# sample21       53      84
# sample22       44      84
# sample23       48      84

# %%
HATCHBACKm.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that married people are less intersted in HATCHBACK than Single.

# %%
sedanmarried = [sample21.iloc[2][0],sample22.iloc[2][0],sample23.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\686530773.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedanmarried = [sample21.iloc[2][0],sample22.iloc[2][0],sample23.iloc[2][0]]

# %%
sedansingle =  [single1.iloc[2][0],single1.iloc[2][0],single1.iloc[2][0]]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\262423041.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedansingle =  [single1.iloc[2][0],single1.iloc[2][0],single1.iloc[2][0]]

# %%
sedanmarried
# Out:
# [np.int64(62), np.int64(65), np.int64(59)]

# %%
sedansingle
# Out:
# [np.int64(38), np.int64(38), np.int64(38)]

# %%
SEDANm = pd.DataFrame({"Married":sedanmarried,"Single":sedansingle},index=["sample21","sample22","sample23"])

# %%
SEDANm
# Out:
#           Married  Single
# sample21       62      38
# sample22       65      38
# sample23       59      38

# %%
SEDANm.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that married people are more intersted in SEDAN than Single.

# %%
# comparision 4

# %%
pd.crosstab(file.Personal_loan,file.Make)
# Out:
# Make           Hatchback  SUV  Sedan
# Personal_loan
# No                   291  181    317
# Yes                  291  116    385

# %%
pd.crosstab(file.Personal_loan,file.Make).plot.bar()
# Out:
# <Axes: xlabel='Personal_loan'>

# %%
file.Personal_loan.value_counts()
# Out:
# Personal_loan
# Yes    792
# No     789
# Name: count, dtype: int64

# %%
pl = file[file.Personal_loan=="Yes"][["Personal_loan","Make"]]

# %%
npl =  file[file.Personal_loan=="No"][["Personal_loan","Make"]]

# %%
yes = pl.groupby("Make").count().rename(columns={"Personal_loan":"Yes"})

# %%
yes
# Out:
#            Yes
# Make
# Hatchback  291
# SUV        116
# Sedan      385

# %%
no = npl.groupby("Make").count().rename(columns={"Personal_loan":"No"})

# %%
no
# Out:
#             No
# Make
# Hatchback  291
# SUV        181
# Sedan      317

# %%
suvy = yes.iloc[1][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\365404302.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvy = yes.iloc[1][0]

# %%
suvn = no.iloc[1][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\21566727.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvn = no.iloc[1][0]

# %%
suvy
# Out:
# np.int64(116)

# %%
suvn
# Out:
# np.int64(181)

# %%
SUVPL = pd.DataFrame({"Yes":suvy,"No":suvn},index=["Personal_loan"])

# %%
SUVPL
# Out:
#                Yes   No
# Personal_loan  116  181

# %%
SUVPL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that without personal_loan people more interested in SUV than personal loan people.

# %%
hatchbacky = yes.iloc[0][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\169447206.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbacky = yes.iloc[0][0]

# %%
hatchbackn = no.iloc[0][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\207178914.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackn = no.iloc[0][0]

# %%
hatchbacky
# Out:
# np.int64(291)

# %%
hatchbackn
# Out:
# np.int64(291)

# %%
HATCHBACKPL = pd.DataFrame({"Yes":hatchbacky,"No":hatchbackn},index=["personal_loan"])

# %%
HATCHBACKPL
# Out:
#                Yes   No
# personal_loan  291  291

# %%
HATCHBACKPL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that without personal_loan people and personal loan people are same interested in HATCHBACK.

# %%
sedany = yes.iloc[2][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3600961971.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedany = yes.iloc[2][0]

# %%
sedann= no.iloc[2][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3690381522.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedann= no.iloc[2][0]

# %%
sedany
# Out:
# np.int64(385)

# %%
sedann
# Out:
# np.int64(317)

# %%
SEDANPL = pd.DataFrame({"Yes":sedany,"No":sedann},index=["personal_loan"])

# %%
SEDANPL
# Out:
#                Yes   No
# personal_loan  385  317

# %%
SEDANPL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that personal_loan people more interested in SUV than without personal loan people.

# %%
#camparision 5

# %%
pd.crosstab(file.House_loan,file.Make)
# Out:
# Make        Hatchback  SUV  Sedan
# House_loan
# No                347  275    432
# Yes               235   22    270

# %%
pd.crosstab(file.House_loan,file.Make).plot.bar()
# Out:
# <Axes: xlabel='House_loan'>

# %%
file.House_loan.value_counts()
# Out:
# House_loan
# No     1054
# Yes     527
# Name: count, dtype: int64

# %%
 nhl = file[file.House_loan=="No"][["House_loan","Make"]]

# %%
 hl = file[file.House_loan=="Yes"][["House_loan","Make"]]

# %%
sample31 = nhl.sample(527).groupby("Make").count().rename(columns={"House_loan":"No"})

# %%
sample31
# Out:
#             No
# Make
# Hatchback  172
# SUV        144
# Sedan      211

# %%
sample32 = nhl.sample(527).groupby("Make").count().rename(columns={"House_loan":"No"})

# %%
sample32
# Out:
#             No
# Make
# Hatchback  174
# SUV        129
# Sedan      224

# %%
sample33 = nhl.sample(527).groupby("Make").count().rename(columns={"House_loan":"No"})

# %%
sample33
# Out:
#             No
# Make
# Hatchback  182
# SUV        131
# Sedan      214

# %%
hl1 = hl.sample(527).groupby("Make").count().rename(columns={"House_loan":"Yes"})

# %%
hl1
# Out:
#            Yes
# Make
# Hatchback  235
# SUV         22
# Sedan      270

# %%
suvnhl = sample31.iloc[1][0],sample32.iloc[1][0],sample33.iloc[1][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2467708622.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvnhl = sample31.iloc[1][0],sample32.iloc[1][0],sample33.iloc[1][0]

# %%
suvhl = hl1.iloc[1][0],hl1.iloc[1][0],hl1.iloc[1][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3844616840.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   suvhl = hl1.iloc[1][0],hl1.iloc[1][0],hl1.iloc[1][0]

# %%
suvnhl
# Out:
# (np.int64(144), np.int64(129), np.int64(131))

# %%
suvhl
# Out:
# (np.int64(22), np.int64(22), np.int64(22))

# %%
SUVHL = pd.DataFrame({"Yes":suvhl,"No":suvnhl},index=["sample31","sample32","sample33"])

# %%
SUVHL
# Out:
#           Yes   No
# sample31   22  144
# sample32   22  129
# sample33   22  131

# %%
SUVHL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that without house_loan people more interested in SUV than house loan people.

# %%
sedannhl = sample31.iloc[2][0],sample32.iloc[2][0],sample33.iloc[2][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3008015132.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedannhl = sample31.iloc[2][0],sample32.iloc[2][0],sample33.iloc[2][0]

# %%
sedanhl= hl1.iloc[2][0],hl1.iloc[2][0],hl1.iloc[2][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3362755250.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sedanhl= hl1.iloc[2][0],hl1.iloc[2][0],hl1.iloc[2][0]

# %%
sedannhl
# Out:
# (np.int64(211), np.int64(224), np.int64(214))

# %%
sedanhl
# Out:
# (np.int64(270), np.int64(270), np.int64(270))

# %%
SEDANHL = pd.DataFrame({"Yes":sedanhl,"No":sedannhl},index=["sample31","sample32","sample33"])

# %%
SEDANHL
# Out:
#           Yes   No
# sample31  270  211
# sample32  270  224
# sample33  270  214

# %%
SEDANHL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that house_loan people more interested in SEDAN than WITHOUT House loan people.

# %%
hatchbacknhl =  sample31.iloc[0][0],sample32.iloc[0][0],sample33.iloc[0][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\2844266360.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbacknhl =  sample31.iloc[0][0],sample32.iloc[0][0],sample33.iloc[0][0]

# %%
hatchbackhl = hl1.iloc[0][0],hl1.iloc[0][0],hl1.iloc[0][0]
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_14832\3250867673.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hatchbackhl = hl1.iloc[0][0],hl1.iloc[0][0],hl1.iloc[0][0]

# %%
hatchbacknhl
# Out:
# (np.int64(172), np.int64(174), np.int64(182))

# %%
hatchbackhl
# Out:
# (np.int64(235), np.int64(235), np.int64(235))

# %%
HATCHBACKHL = pd.DataFrame({"Yes":hatchbackhl,"No":hatchbacknhl},index=["sample31","sample32","sample33"])

# %%
HATCHBACKHL
# Out:
#           Yes   No
# sample31  235  172
# sample32  235  174
# sample33  235  182

# %%
HATCHBACKHL.plot.bar()
# Out:
# <Axes: >

# %%
# it is clearfy that house_loan people more interested in HATCHBACK than WITHOUT House loan people.

# %%
new = pd.DataFrame(file.groupby(["Profession","Gender","Make"])["Make"].count())

# %%
new2 = pd.DataFrame(file.groupby(["Partner_working","Gender","Make"])["Make"].count())

# %%
new
# Out:
#                              Make
# Profession Gender Make
# Business   Female SUV          55
#                   Sedan        50
#            Male   Hatchback   290
#                   SUV          34
#                   Sedan       256
# Salaried   Female Hatchback    15
#                   SUV         118
#                   Sedan        91
#            Male   Hatchback   277
#                   SUV          90
#                   Sedan       305

# %%
new2
# Out:
#                                   Make
# Partner_working Gender Make
# No              Female Hatchback     7
#                        SUV          80
#                        Sedan        64
#                 Male   Hatchback   274
#                        SUV          64
#                        Sedan       224
# Yes             Female Hatchback     8
#                        SUV          93
#                        Sedan        77
#                 Male   Hatchback   293
#                        SUV          60
#                        Sedan       337

# %%
new.plot.bar()
# Out:
# <Axes: xlabel='Profession,Gender,Make'>

# %%
#  It is clearfy that female business are more interested in SUV.
#  It is clearfy that female salaried are more interested in SUV.
#  It is clearfy that male business are more interested in HATCHBACK.
#  It is clearfy that male Salaried are more interested in SEDAN.

# %%
new2.plot.bar()
# Out:
# <Axes: xlabel='Partner_working,Gender,Make'>
